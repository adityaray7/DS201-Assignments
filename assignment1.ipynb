# %% [markdown]
# <a href="https://colab.research.google.com/github/adityaray7/DS201-Assignments/blob/main/assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from scipy import signal
import matplotlib.pyplot as plt

# %%
# Generate a sinusoidal signal with frequency 10Hz and amplitude 1
t = np.linspace(0, 1, 1000)
x = np.sin(2*np.pi*10*t)

# Plot the original, noisy, and filtered signals
plt.plot(t, x, label='Original')
plt.legend()
plt.show()

# %%
# Add some noise to the signal
noise = np.random.normal(0, 0.5, size=len(x))
x_noisy = x + noise

# Define a low-pass filter with cutoff frequency 15Hz
cutoff = 15
nyquist = 0.5 * 1000
order = 4
b, a = signal.butter(order, cutoff/nyquist, btype='low')

# Apply the filter to the noisy signal
x_filtered = signal.filtfilt(b, a, x_noisy)

plt.plot(t, x_noisy, label='Noisy')
plt.legend()
plt.show()
plt.plot(t, x_filtered, label='Filtered')
plt.legend()
plt.show()
